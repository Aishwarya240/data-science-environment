# %%
import numpy, pandas, matplotlib, seaborn, sklearn, plotly
print("All packages working!")

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
plt.plot([1,2,3], [4,5,6])
plt.show()
# Out:
# All packages working!

# %%
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# '/home/aishwarya/data-science-environment'

# %%
os.listdir()
# Out:
# ['environment_test.ipynb',
#  'README.md',
#  'Untitled3.ipynb',
#  '.gitignore',
#  'personal_carbon_footprint_behavior.csv',
#  '.git',
#  '.ipynb_checkpoints']

# %%
import pandas as pd

# Load the CSV
df = pd.read_csv("personal_carbon_footprint_behavior.csv")

# %%
df.head(10)
# Out:
#    user_id day_type transport_mode  distance_km  electricity_kwh  \
# 0        1  Weekend             EV         1.55             6.12
# 1        1  Weekend           Walk        10.04             4.50
# 2        1  Weekday           Walk        15.27             2.81
# 3        1  Weekend           Walk         0.50            10.16
# 4        1  Weekend           Walk         3.60             5.02
# 5        1  Weekday             EV         7.77             5.14
# 6        1  Weekend           Bike         6.87             7.14
# 7        2  Weekend            Bus         0.50             4.76
# 8        2  Weekday           Walk        14.33             8.78
# 9        2  Weekday            Car         9.51             7.78
#
#    renewable_usage_pct food_type  screen_time_hours  waste_generated_kg  \
# 0                    0   Non-Veg                2.4                0.70
# 1                    0     Mixed                4.1                0.54
# ...

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# Count of each unique value
df['eco_actions'].value_counts().plot(kind='bar')

plt.xlabel("Number of Eco Actions")
plt.ylabel("Count")
plt.title("Distribution of Eco Actions")
plt.show()
